# %% [markdown]
# # Scraping Wilayah Kerja Statistik 2020

# %%
import requests
import json
import pandas as pd
import numpy as np
import time
from io import StringIO

# %% [markdown]
# ## Import Data Provinsi

# %%
prov = pd.read_csv('prov.csv')
prov.head()
# Out:
#    kode            nama
# 0    11            ACEH
# 1    12  SUMATERA UTARA
# 2    13  SUMATERA BARAT
# 3    14            RIAU
# 4    15           JAMBI

# %% [markdown]
# ## Ambil Data Semua BPS Kab/Kota Masing-Masing Provinsi

# %%
# base dataframe
df = pd.DataFrame({
    "kode_prov": [],
    "kode_bps": [],
    "nama_bps": [],
    "nama_dagri": []
})

for k in prov['kode']:
    url = 'https://sig.bps.go.id/rest-bridging/getwilayah?level=kabupaten&parent={}'.format(k)
    r = requests.get(url)
    data = r.json()

    df_temp = pd.DataFrame(data)
    df_temp['kode_prov'] = k

    df = pd.concat([df, df_temp], ignore_index=True)

df["kode_prov"] = df["kode_prov"].astype(int)
df.head()
# Out:
#      kode_prov kode_bps           nama_bps              nama_dagri kode_dagri
# 0           11     1101           SIMEULUE           KAB. SIMEULUE      11.09
# 1           11     1102       ACEH SINGKIL       KAB. ACEH SINGKIL      11.10
# 2           11     1103       ACEH SELATAN       KAB. ACEH SELATAN      11.01
# 3           11     1104      ACEH TENGGARA      KAB. ACEH TENGGARA      11.02
# 4           11     1105         ACEH TIMUR         KAB. ACEH TIMUR      11.03
# ..         ...      ...                ...                     ...        ...
# 480         91     9109           TAMBRAUW           KAB. TAMBRAUW      92.09
# 481         91     9110            MAYBRAT            KAB. MAYBRAT      92.10
# 482         91     9111  MANOKWARI SELATAN  KAB. MANOKWARI SELATAN      92.11
# 483         91     9112   PEGUNUNGAN ARFAK   KAB. PEGUNUNGAN ARFAK      92.12
# 484         91     9171             SORONG             KOTA SORONG      92.71
#
# [485 rows x 5 columns]

# %% [markdown]
# ## Export Data BPS Kab/Kota

# %%
df.to_csv('kabupaten.csv', index=False)
df.to_json('kabupaten.json', orient='records')

# %%
from selenium import webdriver
driver = webdriver.Edge()

# input data
kabkota = pd.read_csv('kabupaten.csv')
kabkota.head()
# Out:
#    kode_prov  kode_bps       nama_bps          nama_dagri  kode_dagri
# 0         11      1101       SIMEULUE       KAB. SIMEULUE       11.09
# 1         11      1102   ACEH SINGKIL   KAB. ACEH SINGKIL       11.10
# 2         11      1103   ACEH SELATAN   KAB. ACEH SELATAN       11.01
# 3         11      1104  ACEH TENGGARA  KAB. ACEH TENGGARA       11.02
# 4         11      1105     ACEH TIMUR     KAB. ACEH TIMUR       11.03

# %%
# split data into 5 chunks
kabkota_split = np.array_split(kabkota, 5)
# Out:
#      kode_prov  kode_bps           nama_bps              nama_dagri  \
# 388         72      7204               POSO               KAB. POSO
# 389         72      7205           DONGGALA           KAB. DONGGALA
# 390         72      7206          TOLI-TOLI          KAB. TOLI TOLI
# 391         72      7207               BUOL               KAB. BUOL
# 392         72      7208     PARIGI MOUTONG     KAB. PARIGI MOUTONG
# ..         ...       ...                ...                     ...
# 480         91      9109           TAMBRAUW           KAB. TAMBRAUW
# 481         91      9110            MAYBRAT            KAB. MAYBRAT
# 482         91      9111  MANOKWARI SELATAN  KAB. MANOKWARI SELATAN
# 483         91      9112   PEGUNUNGAN ARFAK   KAB. PEGUNUNGAN ARFAK
# 484         91      9171             SORONG             KOTA SORONG
#
#      kode_dagri
# 388       72.02
# 389       72.03
# 390       72.04
# 391       72.05
# 392       72.08
# ..          ...
# 480       92.09
# 481       92.10
# 482       92.11
# 483       92.12
# 484       92.71
#
# [97 rows x 5 columns]

# %%
latlong = pd.DataFrame({
    "kode_bps": [],
    "latitude": [],
    "longitude": []
})
new_data_list = []
latlong
# Out:
# Empty DataFrame
# Columns: [kode_bps, latitude, longitude]
# Index: []

# %%
def iterateScrape(chunk):
    for i, row in chunk.iterrows():
        url = 'https://www.google.com/maps/search/Badan Pusat Statistik {}, {}'.format(row['nama_bps'], row['nama_dagri'])
        driver.get(url)
        time.sleep(3.5)
        latlong = driver.current_url.split("@")[1].split("/")[0].split(",")
        new_data = {
            "kode_bps": row['kode_bps'],
            "latitude": latlong[0],
            "longitude": latlong[1]
        }

        print("process {} of {}".format(i, len(chunk)))
        new_data_list.append(new_data)

# %%
# iterateScrape(kabkota_split[0])
for chunk in kabkota_split:
    iterateScrape(chunk)
latlong = pd.concat([latlong, pd.DataFrame(new_data_list)], ignore_index=True)
# Out:
# process 0 of 97
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Alamat BPS Indonesia\scraping.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> # iterateScrape(kabkota_split[0])
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> for chunk in kabkota_split:
# ----> <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>     iterateScrape(chunk)
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> latlong = pd.concat([latlong, pd.DataFrame(new_data_list)], ignore_index=True)
#
# d:\Alamat BPS Indonesia\scraping.ipynb Cell 13 line 5
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> url = 'https://www.google.com/maps/search/Badan Pusat Statistik {}, {}'.format(row['nama_bps'], row['nama_dagri'])
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> driver.get(url)
# ----> <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> time.sleep(3.5)
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> latlong = driver.current_url.split("@")[1].split("/")[0].split(",")
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a> new_data = {
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a>     "kode_bps": row['kode_bps'],
#       <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a>     "latitude": latlong[0],
#      <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=9'>10</a>     "longitude": latlong[1]
#      <a href='vscode-notebook-cell:/d%3A/Alamat%20BPS%20Indonesia/scraping.ipynb#X26sZmlsZQ%3D%3D?line=10'>11</a> }
#
# KeyboardInterrupt:

# %%
latlong = pd.concat([latlong, pd.DataFrame(new_data_list)], ignore_index=True)

# %%
temp = pd.merge(kabkota_split[0], latlong, on='kode_bps', how='inner')
# kabkota_split[0]
# get info variable
# latlong
# kabkota_split[0]

# %%
temp
# Out:
#     kode_prov  kode_bps              nama_bps                 nama_dagri  \
# 0          11      1101              SIMEULUE              KAB. SIMEULUE
# 1          11      1102          ACEH SINGKIL          KAB. ACEH SINGKIL
# 2          11      1103          ACEH SELATAN          KAB. ACEH SELATAN
# 3          11      1104         ACEH TENGGARA         KAB. ACEH TENGGARA
# 4          11      1105            ACEH TIMUR            KAB. ACEH TIMUR
# ..        ...       ...                   ...                        ...
# 92         15      1506  TANJUNG JABUNG TIMUR  KAB. TANJUNG JABUNG TIMUR
# 93         15      1507  TANJUNG JABUNG BARAT  KAB. TANJUNG JABUNG BARAT
# 94         15      1508                  TEBO                  KAB. TEBO
# 95         15      1509                 BUNGO                 KAB. BUNGO
# 96         15      1571                 JAMBI                 KOTA JAMBI
#
#     kode_dagri latitude longitude
# 0        11.09        2         9
# 1        11.10        2         9
# 2        11.01        3         9
# 3        11.02        3         9
# 4        11.03        4         9
# ..         ...      ...       ...
# 92       15.07        -         1
# 93       15.06        -         1
# 94       15.09        -         1
# 95       15.08        -         1
# 96       15.71        -         1
#
# [97 rows x 7 columns]
